# %%
import numpy as np
#Code Challenge A:
A7a = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
A7b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)


#Code Challenge B:
B7a = np.array([[1, 	1], [1, 1.0001]])
B7b = np.array([1, 1])

#Code Challenge C:
C7a = np.array([[1, 	1], [1, 1.0001]])
C7b = np.array([1, 1.0001])


#Code Challenge D (In-Class):

D7a = np.array([
    [10, -1, 2, 0, 0],
    [-1, 11, -1, 3, 0],
    [2, -1, 10, -1, 0],
    [0, 3, -1, 8, -2],
    [0, 0, 0, -2, 9]
], dtype=float)

D7b = np.array([
    [1, 2, 3, 0, 0],
    [2, 1, 2, 3, 0],
    [3, 2, 1, 2, 3],
    [0, 3, 2, 1, 2],
    [0, 0, 3, 2, 1]
], dtype=float)


def check_diagonal_dominance(A):
    n = A.shape[0]
    
    strictly_dominant = True
    weakly_dominant = True
    
    for i in range(n):
        diag = abs(A[i, i])
        off_diag_sum = np.sum(np.abs(A[i])) - diag
        
        if diag < off_diag_sum:
            weakly_dominant = False
            strictly_dominant = False
            break
        elif diag == off_diag_sum:
            strictly_dominant = False
    
    if strictly_dominant:
        return "Strictly Diagonally Dominant"
    elif weakly_dominant:
        return "Weakly Diagonally Dominant"
    else:
        return "Not Diagonally Dominant"

print("Challenge 7D Results, Done in class")
print("6a:", check_diagonal_dominance(D7a))
print("6b:", check_diagonal_dominance(D7b))
# Out:
# Challenge 7D Results, Done in class
# 6a: Strictly Diagonally Dominant
# 6b: Not Diagonally Dominant
